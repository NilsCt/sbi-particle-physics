# %%
from sbi_particle_physics.managers.improvements import Improvements
from sbi_particle_physics.managers.backup import Backup
from sbi_particle_physics.config import MODELS_DIR, DATA_DIR

# %%
#directories = [MODELS_DIR / f"training_{x}" for x in range(6,11)]
directories = [MODELS_DIR / f"training_11"]
files = Backup.detect_files(DATA_DIR / "data_2")[-1:] # 1 last files
raw_data, raw_parameters, _ = Backup.load_data(files)

# %%
Improvements.plot_width_by_npoints(directories, raw_data, n_posterior_samples=100)

# %%
Improvements.plot_width_by_npoints_pro(directories, raw_data, n_posterior_samples=100)

# %%
Improvements.plot_width_by_npoints_quantify(directories, raw_data, n_posterior_samples=100)
