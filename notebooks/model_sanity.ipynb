# %%
from sbi_particle_physics.managers.backup import Backup
from sbi_particle_physics.config import MODELS_DIR, DATA_DIR
import torch
from sbi_particle_physics.managers.plotter import Plotter
from sbi_particle_physics.managers.predictions import Predictions

# %%
model = Backup.load_model_for_inference_basic(directory=MODELS_DIR / "training_500", device=torch.device("cpu"))

# %%
data_files = [Backup.detect_files(DATA_DIR / "data_6")[1]]
true_parameters, data, sampled_parameters = Backup.get_true_parameters_simulations_and_sampled_parameters(model, data_files=data_files, n_true=1, n_sampled_parameters=10000)
true_parameter = true_parameters[0]
data1 = data[0]
sampled_parameters1 = sampled_parameters[0]
mean, uncertainty = Predictions.calculate_estimator(sampled_parameters)
print("mean", mean)
print("uncertainty", uncertainty)
print("true parameter", true_parameter)

# %%
Plotter.plot_a_posterior_parameter(sampled_parameters1[:,0], "$C_9$", true_parameter[0], range=(3,5))

# %%
model.simulator.stride = 2
model.simulator.pre_N = 5
model.simulator.preruns = 2
n_sampled_parameters = 10
n_similar = 3

# %%
print(model.posterior)
print(model.normalizer)
print(model.simulator)
print(model.prior)
print(model.neural_network)
print(model.device)

# %%
true_parameter, observed_sample, sampled_parameters = model.get_true_parameters_simulations_and_sampled_parameters(n_true=1, n_points=model.n_points, n_sampled_parameters=n_sampled_parameters)
Plotter.plot_a_posterior(sampled_parameters, true_parameter)
