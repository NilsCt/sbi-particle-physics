# %%
import torch
import numpy as np
from model import Model
from data_manager import DataManager

# %%
print("=" * 80)
print("DIAGNOSTIC CUDA")
print("=" * 80)
print(f"CUDA disponible : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Nombre de GPU : {torch.cuda.device_count()}")
    print(f"GPU actuel : {torch.cuda.current_device()}")
    print(f"Nom du GPU : {torch.cuda.get_device_name(0)}")
    print(f"Mémoire totale : {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("⚠️  CUDA n'est pas disponible - utilisation du CPU")
print("=" * 80)
# Out:
# ================================================================================
# DIAGNOSTIC CUDA
# ================================================================================
# CUDA disponible : False
# ⚠️  CUDA n'est pas disponible - utilisation du CPU
# ================================================================================

# %%
n_samples = 500
n_points = 1000

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

seed = np.random.randint(0, 10000)
stop_after_epochs = 3
model = Model(device, seed, stop_after_epochs)

prior_low_raw = model.to_tensor([3])
prior_high_raw = model.to_tensor([5])
model.set_prior(prior_low_raw, prior_high_raw)

stride = 10
pre_N = 200
preruns = 2
model.set_simulator(stride, pre_N, preruns)
# not necessary to build the nn

# %%
start_index = 15
for i in range(10):
    location = f"data/data{start_index + i}.pt"
    raw_data, raw_parameters = model.simulate_raw_data(n_samples, n_points)
    DataManager.save_data(location, raw_data, raw_parameters, n_samples, n_points, device, seed, stop_after_epochs, stride, pre_N, preruns, prior_low_raw, prior_high_raw)
    print(f"Saved data : raw_data {raw_data.shape}, raw_parameters {raw_parameters.shape}")
    print(f"File : {location}")
# Out:
# Simulating samples:   0%|          | 0/500 [00:00<?, ?it/s]
# /home/hep/nrc25/miniconda3/envs/mlhep/lib/python3.12/site-packages/eos/signal_pdf.py:71: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   log_proposal = pypmc.density.gauss.LocalGauss(sigma)
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# Pre-runs:   0%|          | 0/2 [00:00<?, ?it/s]
# Main run:   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 for i in range(10):
#       3     location = f"data/data{start_index + i}.pt"
# ----> 4     raw_data, raw_parameters = model.simulate_raw_data(n_samples, n_points)
#       5     DataManager.save_data(location, raw_data, raw_parameters, n_samples, n_points, device, seed, stop_after_epochs, stride, pre_N, preruns, prior_low_raw, prior_high_raw)
#       6     print(f"Saved data : raw_data {raw_data.shape}, raw_parameters {raw_parameters.shape}")
#
# File ~/project/sbi-particle-physics/model.py:62, in Model.simulate_raw_data(self, n_samples, n_points)
#      60 def simulate_raw_data(self, n_samples, n_points): # used before creating the normalizer
#      61     raw_parameters = self.draw_raw_parameters_from_prior(n_samples)
# ---> 62     return self.simulator.simulate_samples(raw_parameters, n_points), raw_parameters
#
# File ~/project/sbi-particle-physics/simulator.py:67, in Simulator.simulate_samples(self, raw_parameters, n_points)
#      65 raw_data = torch.zeros((n_samples, n_points, self.point_dim), dtype=torch.float32, device=self.device)
#      66 for i, raw_parameter in enumerate(tqdm(raw_parameters, desc="Simulating samples", leave=True)):
# ---> 67     raw_data[i] = self.simulate_a_sample(raw_parameter, n_points)
#      68 return raw_data
#
# File ~/project/sbi-particle-physics/simulator.py:54, in Simulator.simulate_a_sample(self, raw_parameter, n_points)
#      52 def simulate_a_sample(self, raw_parameter, n_points):
#      53     self.set_eos_parameter(raw_parameter)
# ---> 54     raw_sample, _ = self.distribution.sample_mcmc(
#      55         N=n_points,
#      56         stride=self.stride,
#      57         pre_N=self.pre_N,
#      58         preruns=self.preruns,
#      59         rng=self.rng
#      60     )
#      61     return self.to_tensor(raw_sample)
#
# File ~/miniconda3/envs/mlhep/lib/python3.12/site-packages/eos/signal_pdf.py:98, in SignalPDF.sample_mcmc(self, N, stride, pre_N, preruns, cov_scale, start_point, rng)
#      96 sample_chunks.append(sample_total - 99 * sample_chunk)
#      97 for current_chunk in progressbar(sample_chunks, desc="Main run", leave=False):
# ---> 98     accept_count = accept_count + sampler.run(current_chunk)
#      99 accept_rate  = accept_count / (N * stride) * 100
#     100 eos.info(f'Main run: acceptance rate is {accept_rate:3.0f}%')
#
# File ~/miniconda3/envs/mlhep/lib/python3.12/site-packages/pypmc/sampler/markov_chain.py:214, in AdaptiveMarkovChain.run(self, N, continue_on_NaN)
#     212 if N == 0:
#     213     return 0
# --> 214 self._last_accept_count = super(AdaptiveMarkovChain, self).run(N, continue_on_NaN)
#     215 return self._last_accept_count
#
# File ~/miniconda3/envs/mlhep/lib/python3.12/site-packages/pypmc/sampler/markov_chain.py:137, in MarkovChain.run(self, N, continue_on_NaN)
#     134 for i_N in range(N):
#     135     # propose new point
#     136     proposed_point = self.proposal.propose(self.current_point, self.rng)
# --> 137     proposed_eval  = self.target(proposed_point)
#     139     # log_rho := log(probability to accept point), where log_rho > 0 is meant to imply rho = 1
#     140     log_rho = get_log_rho(proposed_point, proposed_eval)
#
# File ~/miniconda3/envs/mlhep/lib/python3.12/site-packages/pypmc/tools/indicator/_indicator_merge.py:30, in merge_function_with_indicator.<locals>.merged_function(x)
#      28 def merged_function(x):
#      29     if indicator(x):
# ---> 30         return function(x)
#      31     else:
#      32         return alternative
#
# File ~/miniconda3/envs/mlhep/lib/python3.12/site-packages/eos/signal_pdf.py:33, in SignalPDF.log_pdf(self, x)
#      30 for kv, v in zip(self.variables, x):
#      31     kv.set(v)
# ---> 33 return self.evaluate()
#
# KeyboardInterrupt:

# %%
# Saving data
#torch.save({
#    'raw_data': raw_data,
#    'raw_parameters': raw_parameters,
#    'metadata': {
#        'n_samples': n_samples,
#        'n_points': n_points,
#        'device': str(device),
#        'seed': seed,
#        'stop_after_epochs': stop_after_epochs,
#        'stride': stride,
#        'pre_N': pre_N,
#        'preruns': preruns,
#        'prior_low_raw': prior_low_raw.cpu().numpy(),
#        'prior_high_raw': prior_high_raw.cpu().numpy()
#    }
#}, location)

#print(f"Saved data : raw_data {raw_data.shape}, raw_parameters {raw_parameters.shape}")
#print(f"File : {location}")

# %%
# Vérification que les tenseurs sont bien sur le bon device
#print(f"\nDevice utilisé : {device}")
#print(f"Prior low device : {prior_low_raw.device}")
#print(f"Prior high device : {prior_high_raw.device}")
#print(f"Prior (sbi) device : {model.prior.device if hasattr(model.prior, 'device') else 'N/A'}")

# %%
# Vérification finale : où sont les données générées ?
#print(f"\nData générées - Device : {raw_data.device}")
#print(f"Parameters générés - Device : {raw_parameters.device}")
